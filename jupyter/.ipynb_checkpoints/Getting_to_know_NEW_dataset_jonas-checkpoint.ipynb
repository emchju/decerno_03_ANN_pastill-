# %%
import pandas as pd
import numpy as np
import folium
from matplotlib import colors as mcolors
import matplotlib.pyplot as plt
import json
# %matplotlib inline

# %%
with open('../saved_data/data_from_file-NEW.json', 'r') as filename:
    json_file=json.load(filename)
json_file[0]['data']
# Out:
# '{"name": "scenario2192__drone2009", "agent-type": "air", "agent-description": "L2_agent_example", "agent-model": "rotary.drone", "agent-uuid": "e31bf4b4-1d30-4658-b156-6b58df903b88", "levels": ["sensor", "direct execution"], "rate": 3, "stamp": 1681990429.7309468, "type": "HeartBeat"}'

# %%
df = pd.DataFrame(json_file)
df
# Out:
#                             id                          timeStamp  \
# 0     6441231e450c18895ee5c354  2023-04-20T11:33:50.7244548+00:00
# 1     6441231e450c18895ee5c355  2023-04-20T11:33:50.7264919+00:00
# 2     6441231e450c18895ee5c356  2023-04-20T11:33:50.7268827+00:00
# 3     6441231e450c18895ee5c357   2023-04-20T11:33:50.727287+00:00
# 4     6441231e450c18895ee5c358  2023-04-20T11:33:50.7297823+00:00
# ...                        ...                                ...
# 9995  64412332450c18895ee5ea5f  2023-04-20T11:34:10.6414575+00:00
# 9996  64412332450c18895ee5ea60  2023-04-20T11:34:10.6418523+00:00
# 9997  64412332450c18895ee5ea61  2023-04-20T11:34:10.6430215+00:00
# 9998  64412332450c18895ee5ea62  2023-04-20T11:34:10.6442791+00:00
# 9999  64412332450c18895ee5ea63  2023-04-20T11:34:10.6509721+00:00
#
#                                                   topic  \
# 0     waraps/unit/air/simulation/scenario2192__drone...
# 1             waraps/unit/air/real/GN96/sensor/position
# 2     waraps/unit/air/simulation/scenario2192__drone...
# 3     waraps/unit/air/simulation/scenario2192__drone...
# 4                waraps/unit/air/real/GN96/sensor/speed
# ...                                                 ...
# 9995  waraps/unit/air/simulation/scenario2192__drone...
# 9996  waraps/unit/air/simulation/test945__linusdrone...
# 9997  waraps/unit/air/simulation/scenario2192__drone...
# 9998  waraps/unit/air/simulation/test945__linusdrone...
# 9999  waraps/unit/air/simulation/test945__linusdrone...
#
#                                                    data
# 0     {"name": "scenario2192__drone2009", "agent-typ...
# 1     {"latitude":58.0179,"longitude":15.7929,"altit...
# 2     {"name": "scenario2192__drone2009", "rate": 3,...
# 3     {"latitude": 57.76837112643054, "longitude": 1...
# 4                                                162.05
# ...                                                 ...
# 9995                                 -40.60269077073514
# 9996  {"name": "test945__linusdrone", "agent-type": ...
# 9997  wss://ome.waraps.org:3334/app/scenario2192__dr...
# 9998  {"name": "test945__linusdrone", "rate": 3, "se...
# 9999  {"latitude": 57.80601350060965, "longitude": 1...
#
# [10000 rows x 4 columns]

# %%
topic = df['topic']
topic
# Out:
# 0       waraps/unit/air/simulation/scenario2192__drone...
# 1               waraps/unit/air/real/GN96/sensor/position
# 2       waraps/unit/air/simulation/scenario2192__drone...
# 3       waraps/unit/air/simulation/scenario2192__drone...
# 4                  waraps/unit/air/real/GN96/sensor/speed
#                               ...
# 9995    waraps/unit/air/simulation/scenario2192__drone...
# 9996    waraps/unit/air/simulation/test945__linusdrone...
# 9997    waraps/unit/air/simulation/scenario2192__drone...
# 9998    waraps/unit/air/simulation/test945__linusdrone...
# 9999    waraps/unit/air/simulation/test945__linusdrone...
# Name: topic, Length: 10000, dtype: object

# %%
payload = df['data']
payload
# Out:
# 0       {"name": "scenario2192__drone2009", "agent-typ...
# 1       {"latitude":58.0179,"longitude":15.7929,"altit...
# 2       {"name": "scenario2192__drone2009", "rate": 3,...
# 3       {"latitude": 57.76837112643054, "longitude": 1...
# 4                                                  162.05
#                               ...
# 9995                                   -40.60269077073514
# 9996    {"name": "test945__linusdrone", "agent-type": ...
# 9997    wss://ome.waraps.org:3334/app/scenario2192__dr...
# 9998    {"name": "test945__linusdrone", "rate": 3, "se...
# 9999    {"latitude": 57.80601350060965, "longitude": 1...
# Name: data, Length: 10000, dtype: object

# %%
current_load = payload[1]
current_payload = json.loads(current_load)
current_payload['latitude']
# Out:
# 58.0179

# %%
time_list = df['timeStamp']
time_list
# Out:
# 0       2023-04-20T11:33:50.7244548+00:00
# 1       2023-04-20T11:33:50.7264919+00:00
# 2       2023-04-20T11:33:50.7268827+00:00
# 3        2023-04-20T11:33:50.727287+00:00
# 4       2023-04-20T11:33:50.7297823+00:00
#                       ...
# 9995    2023-04-20T11:34:10.6414575+00:00
# 9996    2023-04-20T11:34:10.6418523+00:00
# 9997    2023-04-20T11:34:10.6430215+00:00
# 9998    2023-04-20T11:34:10.6442791+00:00
# 9999    2023-04-20T11:34:10.6509721+00:00
# Name: timeStamp, Length: 10000, dtype: object

# %%
id_ = []
time = []
lng = []
lat = []
simulation = []
speed = []
agent = []
for i in range(0, len(topic)):

    # Examples:
    # Simulated: waraps/unit/air/simulation/arducopter21/sensor/position
    # Real: waraps/unit/air/real/dji-pro/sensor/position 13
    current_topic = topic[i]
    if current_topic[51:] == 'sensor/position':
        if current_topic[0:27] == 'waraps/unit/air/simulation/':
            current_agent = current_topic[27:-16]
            current_status = True
        if current_topic[0:21] == 'waraps/unit/air/real/':
            current_agent = current_topic[21:-16]
            current_status = False
        id_.append(current_agent)
        simulation.append(current_status)
        current_payload = json.loads(payload[i])
        time.append(time_list[i])
        lat.append(current_payload['latitude'])
        lng.append(current_payload['longitude'])
        agent.append(current_agent)

# %%
headings = ['id', 'agent', 'time', 'lng', 'lat', 'simulation']

# %%
data = list(zip(id_, agent, time, lng, lat, simulation))

# %%
df = pd.DataFrame(data, columns = headings)

# %%
df.head()
# Out:
#                         id                                              agent  \
# 0  scenario2192__drone2009  {'latitude': 57.76837112643054, 'longitude': 1...
# 1  scenario3547__drone6450  {'latitude': 57.75879257894278, 'longitude': 1...
# 2  scenario3547__drone2801  {'latitude': 57.75682358277309, 'longitude': 1...
# 3  scenario7015__drone9745  {'latitude': -15.546721676808133, 'longitude':...
# 4  scenario2192__drone3897  {'latitude': 57.77141083372993, 'longitude': 1...
#
#                                 time        lng        lat  simulation
# 0   2023-04-20T11:33:50.727287+00:00  16.764594  57.768371        True
# 1  2023-04-20T11:33:50.7301761+00:00  16.678406  57.758793        True
# 2  2023-04-20T11:33:50.8546359+00:00  16.685830  57.756824        True
# 3  2023-04-20T11:33:50.8659209+00:00 -40.757673 -15.546722        True
# 4  2023-04-20T11:33:50.8765577+00:00  16.757722  57.771411        True

# %%
filter_dataset = df['simulation'].values == True
dataset_real = df.loc[filter_dataset]
dataset_real.head()
# Out:
#           id          time        lng        lat  simulation
# 0  Mini-UGV1  1.675678e+09  15.407262  58.323460        True
# 2       cam0  1.675678e+09  16.682761  57.760557        True
# 3       cam1  1.675678e+09  16.683601  57.760546        True
# 4       cam2  1.675678e+09  16.681921  57.760569        True
# 5  Mini-UGV1  1.675678e+09  15.407262  58.323460        True

# %%
# I now want to se a list of all real agents in the data set
dataset_real_agent_list = dataset_real.groupby('id').mean()
dataset_real_agent_list
# Out:
#                           time        lng        lat  simulation
# id
# Mini-UGV1         1.675678e+09  15.407530  58.323415         1.0
# anomaly_detector  1.675678e+09  16.693900  57.756100         1.0
# cam0              1.675678e+09  16.682761  57.760557         1.0
# cam1              1.675678e+09  16.683601  57.760546         1.0
# cam2              1.675678e+09  16.681921  57.760569         1.0

# %%
list_real_agents = dataset_real_agent_list.index.values.tolist()
list_real_agents
# Out:
# ['Mini-UGV1', 'anomaly_detector', 'cam0', 'cam1', 'cam2']

# %%
filter_dataset = dataset_real['id'].values == 'Mini-UGV1'
dataset_real_one_agent = dataset_real.loc[filter_dataset]
dataset_real_one_agent.head()
# Out:
#           id          time        lng       lat  simulation
# 0  Mini-UGV1  1.675678e+09  15.407262  58.32346        True
# 5  Mini-UGV1  1.675678e+09  15.407262  58.32346        True
# 6  Mini-UGV1  1.675678e+09  15.407262  58.32346        True
# 7  Mini-UGV1  1.675678e+09  15.407262  58.32346        True
# 8  Mini-UGV1  1.675678e+09  15.407262  58.32346        True

# %%
time_intervalls = []
all_time = dataset_real_one_agent['time'].values
for i in range(0, len(all_time)-1):
    diff = all_time[i+1] - all_time[i]
    time_intervalls.append(diff)
time_intervalls
# Out:
# [0.17881059646606445,
#  0.09720444679260254,
#  0.1278536319732666,
#  0.06078839302062988,
#  0.07230305671691895,
#  0.03168654441833496,
#  0.05952596664428711,
#  0.11242985725402832,
#  0.1967012882232666,
#  0.06752538681030273,
#  0.11338567733764648,
#  0.08048844337463379,
#  0.2128598690032959,
#  0.07762598991394043,
#  0.1909644603729248,
#  0.11423134803771973,
#  0.15828347206115723,
#  0.05831170082092285,
#  0.10345268249511719,
#  0.09388017654418945,
#  0.10922455787658691,
#  0.06893253326416016,
#  0.07883310317993164,
#  0.07345438003540039,
#  0.09265279769897461,
#  0.06568217277526855,
#  0.12952542304992676,
#  0.08811664581298828,
#  0.10950040817260742,
#  0.07475042343139648,
#  0.4589552879333496,
#  0.010887622833251953,
#  0.006959199905395508,
#  0.010477542877197266,
#  0.009876489639282227,
#  0.00738525390625,
#  0.030323505401611328,
#  0.0794074535369873,
#  0.05361580848693848,
#  0.06481409072875977,
#  0.05772519111633301,
#  0.06875419616699219,
#  0.03745627403259277,
#  0.08181190490722656,
#  0.05046510696411133,
#  0.08532428741455078,
#  0.07288169860839844,
#  0.08527159690856934,
#  0.058072805404663086,
#  0.05655813217163086,
#  0.05481123924255371,
#  0.259296178817749,
#  0.24605011940002441,
#  0.2357931137084961,
#  0.26737117767333984,
#  0.24988889694213867,
#  0.24394965171813965,
#  0.5825619697570801,
#  0.25272679328918457,
#  0.24631524085998535,
#  0.2569742202758789,
#  0.24066686630249023,
#  0.2593040466308594,
#  0.23943734169006348,
#  0.2666301727294922,
#  0.23591041564941406,
#  0.2588825225830078,
#  0.24248170852661133,
#  0.2562389373779297,
#  0.23980188369750977,
#  0.26221776008605957,
#  0.25522923469543457,
#  0.24826431274414062,
#  0.2378711700439453,
#  0.25400781631469727,
#  0.24737048149108887,
#  0.2571587562561035,
#  0.23856711387634277,
#  0.26065993309020996,
#  0.24342942237854004,
#  0.2585747241973877,
#  0.24338412284851074,
#  0.25979137420654297,
#  0.2368016242980957,
#  0.2579953670501709,
#  0.24138712882995605,
#  0.32465529441833496,
#  ...]

# %%
len(dataset_real_one_agent)
# Out:
# 2124

# %%
x = dataset_real_one_agent['lng'].values 
y = dataset_real_one_agent['lat'].values
N = len(x)
colors = np.random.rand(N)

plt.scatter(x, y, c=colors, alpha=0.5)
plt.title('Movement of agent Mini-UGV1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %%
def plot(dataset, agent):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(dataset['lng'].values)
    ax.grid(True)

    plt.title(agent)
    #plt.xlabel(dataset['Tidpunkt'].values)
    plt.ylabel('Longitude')

# %%
plot(dataset_real_one_agent, 'Mini-UGV1')

# %%
x = dataset_real_one_agent['lng'].values 
y = dataset_real_one_agent['lat'].values
N = len(x)
colors = np.random.rand(N)

plt.scatter(x, y, c=colors, alpha=0.5)
plt.title('Movement of agent Mini-UGV1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %%
data_ai = dataset_real_one_agent['lng'].values.reshape(-1, 1)
data_ai
# Out:
# array([[15.4072616],
#        [15.4072616],
#        [15.4072616],
#        ...,
#        [15.4074812],
#        [15.4074812],
#        [15.4074812]])

# %%
# Scaling the training_set (use standardisation or normalization)
# Since our output signal is continous (sigmoid function)
# --> NORMALIZATION is recommended
from sklearn.preprocessing import MinMaxScaler

# Implement a scaler with value (range) between 0 and 1
scaler = MinMaxScaler(feature_range = (0,1))

# %%
# Apply scaler in training set
training_set_scaled = scaler.fit_transform(data_ai)

# %%
# Convert series to supervised learning - input predicting pollution outputs
from pandas import concat

def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# Frame as supervised learning
reframed_data = series_to_supervised(training_set_scaled, 1, 1)
reframed_data
# Out:
#         var1(t-1)   var1(t)
# 1        0.838042  0.838040
# 2        0.838040  0.838038
# 3        0.838038  0.838035
# 4        0.838035  0.838031
# 5        0.838031  0.838029
# ...           ...       ...
# 126292   0.819252  0.819252
# 126293   0.819252  0.819252
# 126294   0.819252  0.819252
# 126295   0.819252  0.819252
# 126296   0.819252  0.819252
#
# [126296 rows x 2 columns]

# %%
# 80% data for training and 20% data for test 
# Training --> 126 297 * 0.8 = 101 037
# Test --> 126 297 - 101 037 = 25 260
reframed_values = reframed_data.values
training_values = reframed_values[:101037, :]
len(training_values)
# Out:
# 101037

# %%
test_values = reframed_values[101037:, :]
len(test_values)
# Out:
# 25259

# %%
# Split into input and outputs --> all values exept the last column is X, the last column is y
train_X, train_y = training_values[:, :-1], training_values[:, -1]

# %%
test_X, test_y = test_values[:, :-1], test_values[:, -1]

# %%
# Reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (101037, 1, 1) (101037,) (25259, 1, 1) (25259,)

# %%
# Neural network
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')

# %%
# Training the network
history = model.fit(train_X, train_y, epochs=100, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/100
# 1404/1404 - 11s - loss: 0.0612 - val_loss: 0.0176 - 11s/epoch - 8ms/step
# Epoch 2/100
# 1404/1404 - 5s - loss: 0.0089 - val_loss: 0.0082 - 5s/epoch - 4ms/step
# Epoch 3/100
# 1404/1404 - 5s - loss: 0.0049 - val_loss: 0.0036 - 5s/epoch - 3ms/step
# Epoch 4/100
# 1404/1404 - 5s - loss: 0.0042 - val_loss: 0.0030 - 5s/epoch - 4ms/step
# Epoch 5/100
# 1404/1404 - 6s - loss: 0.0039 - val_loss: 0.0040 - 6s/epoch - 4ms/step
# Epoch 6/100
# 1404/1404 - 5s - loss: 0.0040 - val_loss: 0.0084 - 5s/epoch - 4ms/step
# Epoch 7/100
# 1404/1404 - 5s - loss: 0.0042 - val_loss: 0.0041 - 5s/epoch - 4ms/step
# Epoch 8/100
# 1404/1404 - 5s - loss: 0.0040 - val_loss: 0.0025 - 5s/epoch - 4ms/step
# Epoch 9/100
# 1404/1404 - 5s - loss: 0.0035 - val_loss: 0.0031 - 5s/epoch - 4ms/step
# Epoch 10/100
# 1404/1404 - 5s - loss: 0.0026 - val_loss: 0.0023 - 5s/epoch - 4ms/step
# Epoch 11/100
# 1404/1404 - 5s - loss: 0.0026 - val_loss: 0.0021 - 5s/epoch - 4ms/step
# Epoch 12/100
# 1404/1404 - 5s - loss: 0.0025 - val_loss: 0.0011 - 5s/epoch - 4ms/step
# Epoch 13/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0010 - 6s/epoch - 4ms/step
# Epoch 14/100
# 1404/1404 - 5s - loss: 0.0023 - val_loss: 0.0018 - 5s/epoch - 4ms/step
# Epoch 15/100
# 1404/1404 - 5s - loss: 0.0025 - val_loss: 0.0011 - 5s/epoch - 3ms/step
# Epoch 16/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0019 - 6s/epoch - 4ms/step
# Epoch 17/100
# 1404/1404 - 5s - loss: 0.0022 - val_loss: 0.0024 - 5s/epoch - 4ms/step
# Epoch 18/100
# 1404/1404 - 5s - loss: 0.0024 - val_loss: 0.0026 - 5s/epoch - 4ms/step
# Epoch 19/100
# 1404/1404 - 5s - loss: 0.0026 - val_loss: 8.6714e-04 - 5s/epoch - 4ms/step
# Epoch 20/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0027 - 6s/epoch - 4ms/step
# Epoch 21/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0018 - 6s/epoch - 4ms/step
# Epoch 22/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0040 - 6s/epoch - 4ms/step
# Epoch 23/100
# 1404/1404 - 5s - loss: 0.0026 - val_loss: 0.0021 - 5s/epoch - 4ms/step
# Epoch 24/100
# 1404/1404 - 5s - loss: 0.0029 - val_loss: 0.0018 - 5s/epoch - 4ms/step
# Epoch 25/100
# 1404/1404 - 5s - loss: 0.0023 - val_loss: 0.0024 - 5s/epoch - 4ms/step
# Epoch 26/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0023 - 6s/epoch - 4ms/step
# Epoch 27/100
# 1404/1404 - 5s - loss: 0.0028 - val_loss: 0.0012 - 5s/epoch - 4ms/step
# Epoch 28/100
# 1404/1404 - 5s - loss: 0.0025 - val_loss: 0.0033 - 5s/epoch - 4ms/step
# Epoch 29/100
# 1404/1404 - 5s - loss: 0.0025 - val_loss: 0.0027 - 5s/epoch - 4ms/step
# Epoch 30/100
# 1404/1404 - 5s - loss: 0.0024 - val_loss: 0.0028 - 5s/epoch - 4ms/step
# Epoch 31/100
# 1404/1404 - 5s - loss: 0.0021 - val_loss: 0.0025 - 5s/epoch - 3ms/step
# Epoch 32/100
# 1404/1404 - 5s - loss: 0.0027 - val_loss: 8.6315e-04 - 5s/epoch - 4ms/step
# Epoch 33/100
# 1404/1404 - 5s - loss: 0.0022 - val_loss: 0.0024 - 5s/epoch - 4ms/step
# Epoch 34/100
# 1404/1404 - 5s - loss: 0.0023 - val_loss: 0.0018 - 5s/epoch - 4ms/step
# Epoch 35/100
# 1404/1404 - 5s - loss: 0.0025 - val_loss: 0.0021 - 5s/epoch - 4ms/step
# Epoch 36/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0013 - 6s/epoch - 4ms/step
# Epoch 37/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0030 - 6s/epoch - 4ms/step
# Epoch 38/100
# 1404/1404 - 7s - loss: 0.0026 - val_loss: 0.0019 - 7s/epoch - 5ms/step
# Epoch 39/100
# 1404/1404 - 5s - loss: 0.0023 - val_loss: 0.0028 - 5s/epoch - 4ms/step
# Epoch 40/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0015 - 6s/epoch - 4ms/step
# Epoch 41/100
# 1404/1404 - 7s - loss: 0.0026 - val_loss: 0.0015 - 7s/epoch - 5ms/step
# Epoch 42/100
# 1404/1404 - 7s - loss: 0.0023 - val_loss: 0.0026 - 7s/epoch - 5ms/step
# Epoch 43/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0028 - 6s/epoch - 4ms/step
# Epoch 44/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0020 - 6s/epoch - 4ms/step
# Epoch 45/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0035 - 6s/epoch - 4ms/step
# Epoch 46/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0021 - 6s/epoch - 4ms/step
# Epoch 47/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 8.8521e-04 - 6s/epoch - 4ms/step
# Epoch 48/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0014 - 6s/epoch - 5ms/step
# Epoch 49/100
# 1404/1404 - 7s - loss: 0.0023 - val_loss: 0.0030 - 7s/epoch - 5ms/step
# Epoch 50/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0033 - 6s/epoch - 4ms/step
# Epoch 51/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0021 - 6s/epoch - 4ms/step
# Epoch 52/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0017 - 6s/epoch - 4ms/step
# Epoch 53/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0022 - 6s/epoch - 4ms/step
# Epoch 54/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0028 - 6s/epoch - 4ms/step
# Epoch 55/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0011 - 6s/epoch - 4ms/step
# Epoch 56/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0047 - 6s/epoch - 4ms/step
# Epoch 57/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0049 - 6s/epoch - 4ms/step
# Epoch 58/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0017 - 6s/epoch - 4ms/step
# Epoch 59/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0026 - 6s/epoch - 4ms/step
# Epoch 60/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0021 - 6s/epoch - 4ms/step
# Epoch 61/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0017 - 6s/epoch - 4ms/step
# Epoch 62/100
# 1404/1404 - 6s - loss: 0.0027 - val_loss: 0.0012 - 6s/epoch - 5ms/step
# Epoch 63/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0010 - 6s/epoch - 5ms/step
# Epoch 64/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0016 - 6s/epoch - 4ms/step
# Epoch 65/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0011 - 6s/epoch - 4ms/step
# Epoch 66/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0022 - 6s/epoch - 4ms/step
# Epoch 67/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0014 - 6s/epoch - 4ms/step
# Epoch 68/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 9.9259e-04 - 6s/epoch - 4ms/step
# Epoch 69/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 8.0729e-04 - 6s/epoch - 4ms/step
# Epoch 70/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0022 - 6s/epoch - 4ms/step
# Epoch 71/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 9.0852e-04 - 6s/epoch - 4ms/step
# Epoch 72/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0012 - 6s/epoch - 4ms/step
# Epoch 73/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0014 - 6s/epoch - 4ms/step
# Epoch 74/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0016 - 6s/epoch - 4ms/step
# Epoch 75/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0015 - 6s/epoch - 4ms/step
# Epoch 76/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 0.0013 - 6s/epoch - 4ms/step
# Epoch 77/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0014 - 6s/epoch - 4ms/step
# Epoch 78/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0015 - 6s/epoch - 4ms/step
# Epoch 79/100
# 1404/1404 - 6s - loss: 0.0027 - val_loss: 8.1406e-04 - 6s/epoch - 4ms/step
# Epoch 80/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0023 - 6s/epoch - 4ms/step
# Epoch 81/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0011 - 6s/epoch - 5ms/step
# Epoch 82/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0025 - 6s/epoch - 4ms/step
# Epoch 83/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0019 - 6s/epoch - 4ms/step
# Epoch 84/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 0.0018 - 6s/epoch - 4ms/step
# Epoch 85/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0018 - 6s/epoch - 4ms/step
# Epoch 86/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0021 - 6s/epoch - 4ms/step
# Epoch 87/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 0.0023 - 6s/epoch - 4ms/step
# Epoch 88/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0012 - 6s/epoch - 4ms/step
# Epoch 89/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0024 - 6s/epoch - 4ms/step
# Epoch 90/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0014 - 6s/epoch - 4ms/step
# Epoch 91/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 0.0034 - 6s/epoch - 4ms/step
# Epoch 92/100
# 1404/1404 - 6s - loss: 0.0020 - val_loss: 8.4960e-04 - 6s/epoch - 4ms/step
# Epoch 93/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0042 - 6s/epoch - 4ms/step
# Epoch 94/100
# 1404/1404 - 6s - loss: 0.0022 - val_loss: 0.0020 - 6s/epoch - 4ms/step
# Epoch 95/100
# 1404/1404 - 6s - loss: 0.0023 - val_loss: 0.0011 - 6s/epoch - 4ms/step
# Epoch 96/100
# 1404/1404 - 6s - loss: 0.0024 - val_loss: 0.0015 - 6s/epoch - 4ms/step
# Epoch 97/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0032 - 6s/epoch - 5ms/step
# Epoch 98/100
# 1404/1404 - 6s - loss: 0.0025 - val_loss: 0.0012 - 6s/epoch - 4ms/step
# Epoch 99/100
# 1404/1404 - 6s - loss: 0.0021 - val_loss: 0.0037 - 6s/epoch - 4ms/step
# Epoch 100/100
# 1404/1404 - 6s - loss: 0.0026 - val_loss: 0.0019 - 6s/epoch - 4ms/step

# %%
# Plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make a prediction
y_pred = model.predict(test_X)

# %%
def plot_result(y_pred, y_test, agent):
    
    # Visualising the results      
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    fig.autofmt_xdate(rotation=45)
    ax.plot(y_pred, label='predicted')
    ax.plot(y_test, label='real value')
    ax.grid(True)
    
    title = 'LONGITUDE for ' + agent
    plt.title(title)
    #plt.xlabel(dataset['Tidpunkt'].values)
    plt.ylabel('Longitude')
    plt.legend()
    plt.show()

# %%
plot_result(y_pred, test_y, 'DJI0')
